# %%
import pandas as pd

# %%
### Vamos a hacer otro dataset de información del fifa
fifa18 = pd.read_csv("infoFifa/players_18.csv")
fifa19 = pd.read_csv("infoFifa/players_19.csv")
fifa20 = pd.read_csv("infoFifa/players_20.csv")
fifa21 = pd.read_csv("infoFifa/players_21.csv")
fifa22 = pd.read_csv("infoFifa/players_22.csv")
fifa23 = pd.read_csv("infoFifa/players_23.csv")
fifa24 = pd.read_csv("infoFifa/players_24.csv")
# Out:
# /var/folders/j5/9lpkspn53fz9cq8v48z2qbl00000gn/T/ipykernel_21821/2294427179.py:2: DtypeWarning: Columns (81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa18 = pd.read_csv("infoFifa/players_18.csv")
# /var/folders/j5/9lpkspn53fz9cq8v48z2qbl00000gn/T/ipykernel_21821/2294427179.py:6: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa22 = pd.read_csv("infoFifa/players_22.csv")
# /var/folders/j5/9lpkspn53fz9cq8v48z2qbl00000gn/T/ipykernel_21821/2294427179.py:7: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa23 = pd.read_csv("infoFifa/players_23.csv")
# /var/folders/j5/9lpkspn53fz9cq8v48z2qbl00000gn/T/ipykernel_21821/2294427179.py:8: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa24 = pd.read_csv("infoFifa/players_24.csv")

# %%
ligas = ["English Premier League","Italian Serie A","French Ligue 1", "German 1. Bundesliga","Spain Primera Division"]
fifa18_filtrado = fifa18[fifa18["league_name"].isin(ligas)]

# %%
columns = ["short_name","long_name","player_positions", "height_cm", "weight_kg", "work_rate", "body_type",
           "pace", "shooting", "passing", "dribbling",	"defending","physic",
           "movement_acceleration",	"movement_sprint_speed","movement_reactions",	"movement_balance", "power_stamina",	"power_strength"
]

# %%
fifa18_filtrado = fifa18_filtrado[columns]

# %%
fifa19_filtrado = fifa19[fifa19["league_name"].isin(ligas)]
fifa19_filtrado= fifa19_filtrado[columns]

fifa20_filtrado = fifa20[fifa20["league_name"].isin(ligas)]
fifa20_filtrado= fifa20_filtrado[columns]

fifa21_filtrado = fifa21[fifa21["league_name"].isin(ligas)]
fifa21_filtrado= fifa21_filtrado[columns]

fifa22_filtrado = fifa22[fifa22["league_name"].isin(ligas)]
fifa22_filtrado= fifa22_filtrado[columns]

# %%
ligas_v2 = ["Premier League","Serie A","Bundesliga","La Liga","Ligue 1"]
fifa23_filtrado = fifa23[fifa23["league_name"].isin(ligas_v2)]
fifa23_filtrado = fifa23_filtrado[columns]
fifa23_filtrado.drop_duplicates(subset=['short_name'],inplace=True)

# %%
fifa24_filtrado = fifa24[fifa24["league_name"].isin(ligas_v2)]
fifa24_filtrado = fifa24_filtrado[columns]
fifa24_filtrado.drop_duplicates(subset=['short_name'],inplace=True)

# %%
fifa18_filtrado["season"]="18/19"
fifa19_filtrado["season"]="19/20"
fifa20_filtrado["season"]="20/21"
fifa21_filtrado["season"]="21/22"
fifa22_filtrado["season"]="22/23"
fifa23_filtrado["season"]="23/24"
fifa24_filtrado["season"]="24/25"

# %%
df_fifa = pd.concat([fifa18_filtrado,fifa19_filtrado, fifa21_filtrado,fifa21_filtrado,
                     fifa22_filtrado,fifa23_filtrado,fifa24_filtrado], axis=0)

# %%
df_fifa
# Out:
#                short_name                            long_name  \
# 0       Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 1                L. Messi       Lionel Andrés Messi Cuccittini
# 2                M. Neuer                   Manuel Peter Neuer
# 3               L. Suárez             Luis Alberto Suárez Díaz
# 4                  Neymar        Neymar da Silva Santos Júnior
# ...                   ...                                  ...
# 179721        A. Adilovic                       Adnan Adilovic
# 179819           A. Parry                         Andrew Parry
# 179933       T. Wölbitsch                       Timo Wölbitsch
# 179970           M. Rocca                        Michele Rocca
# 180005         M. Fissore                       Matteo Fissore
#
#        player_positions  height_cm  weight_kg      work_rate  \
# 0                LW, ST        185         80       High/Low
# 1                    RW        170         72  Medium/Medium
# 2                    GK        193         92  Medium/Medium
# 3                    ST        182         86    High/Medium
# 4                    LW        175         68    High/Medium
# ...                 ...        ...        ...            ...
# 179721               GK        194         93  Medium/Medium
# 179819      CDM, CB, RB        179         73    Medium/High
# 179933               CM        182         70  Medium/Medium
# 179970               CM        177         68    High/Medium
# 180005               CB        180         75     Low/Medium
#
#                body_type  pace  shooting  passing  dribbling  defending  \
# 0                 Unique  90.0      93.0     82.0       90.0       33.0
# 1                 Unique  89.0      90.0     86.0       96.0       26.0
# 2          Normal (185+)   NaN       NaN      NaN        NaN        NaN
# 3       Normal (170-185)  82.0      90.0     79.0       87.0       42.0
# 4                 Unique  92.0      84.0     79.0       95.0       30.0
# ...                  ...   ...       ...      ...        ...        ...
# 179721     Normal (185+)   NaN       NaN      NaN        NaN        NaN
# 179819  Normal (170-185)  58.0      40.0     46.0       42.0       47.0
# 179933  Normal (170-185)  59.0      36.0     49.0       52.0       42.0
# 179970    Lean (170-185)  63.0      41.0     44.0       47.0       41.0
# 180005    Lean (170-185)  58.0      26.0     28.0       29.0       44.0
#
#         physic  movement_acceleration  movement_sprint_speed  \
# 0         80.0                     89                     91
# 1         61.0                     92                     87
# 2          NaN                     58                     61
# 3         81.0                     88                     77
# 4         60.0                     94                     90
# ...        ...                    ...                    ...
# 179721     NaN                     49                     48
# 179819    60.0                     58                     58
# 179933    57.0                     64                     54
# 179970    57.0                     62                     63
# 180005    53.0                     61                     55
#
#         movement_reactions  movement_balance  power_stamina  power_strength  \
# 0                       96                63             92              80
# 1                       95                95             73              59
# 2                       85                35             44              83
# 3                       93                60             89              80
# 4                       88                82             78              53
# ...                    ...               ...            ...             ...
# 179721                  56                55             35              65
# 179819                  48                57             62              64
# 179933                  56                55             44              64
# 179970                  46                65             58              55
# 180005                  46                65             55              55
#
#        season
# 0       18/19
# 1       18/19
# 2       18/19
# 3       18/19
# 4       18/19
# ...       ...
# 179721  24/25
# 179819  24/25
# 179933  24/25
# 179970  24/25
# 180005  24/25
#
# [38568 rows x 20 columns]

# %% [markdown]
# Hay que preprocesar por aqui por que hay mucho NaN

# %%
df_fifa.describe()
# Out:
#           height_cm     weight_kg          pace      shooting       passing  \
# count  38568.000000  38568.000000  34390.000000  34390.000000  34390.000000
# mean     182.050534     75.610765     68.543617     55.482466     60.644577
# std        6.608186      7.005135     11.044261     14.624282     11.020265
# min      159.000000     51.000000     21.000000     14.000000     25.000000
# 25%      178.000000     70.000000     62.000000     45.000000     53.000000
# 50%      182.000000     75.000000     69.000000     58.000000     61.000000
# 75%      187.000000     80.000000     76.000000     67.000000     69.000000
# max      206.000000    110.000000     97.000000     94.000000     94.000000
#
#           dribbling     defending        physic  movement_acceleration  \
# count  34390.000000  34390.000000  34390.000000           38568.000000
# mean      65.756063     53.904129     65.270137              65.377308
# std       10.661634     18.145844     10.403537              14.561252
# min       26.000000     15.000000     28.000000              12.000000
# 25%       60.000000     37.000000     58.000000              58.000000
# 50%       67.000000     59.000000     66.000000              68.000000
# 75%       73.000000     69.000000     73.000000              76.000000
# max       96.000000     91.000000     91.000000              97.000000
#
#        movement_sprint_speed  movement_reactions  movement_balance  \
# count           38568.000000        38568.000000      38568.000000
# mean               65.520068           65.429060         64.285729
# std                14.318983           10.018905         14.324394
# min                13.000000           26.000000         10.000000
# 25%                58.000000           58.000000         56.000000
# 50%                68.000000           66.000000         66.000000
# 75%                75.000000           73.000000         75.000000
# max                97.000000           96.000000         97.000000
#
#        power_stamina  power_strength
# count   38568.000000    38568.000000
# mean       63.046593       65.390168
# std        15.923101       12.816516
# min        13.000000       16.000000
# 25%        55.000000       57.000000
# 50%        66.000000       67.000000
# 75%        74.000000       75.000000
# max        97.000000       96.000000

# %% [markdown]
# Vamos a quitar los porteros del estudio por que no tienen información para muchas variables

# %%
df_fifa_noGK = df_fifa[df_fifa["player_positions"] != "GK"]

# %%
df_fifa_noGK.describe()
# Out:
#           height_cm     weight_kg          pace      shooting       passing  \
# count  34390.000000  34390.000000  34390.000000  34390.000000  34390.000000
# mean     181.184472     74.784763     68.543617     55.482466     60.644577
# std        6.285130      6.664801     11.044261     14.624282     11.020265
# min      159.000000     51.000000     21.000000     14.000000     25.000000
# 25%      177.000000     70.000000     62.000000     45.000000     53.000000
# 50%      181.000000     75.000000     69.000000     58.000000     61.000000
# 75%      186.000000     79.000000     76.000000     67.000000     69.000000
# max      206.000000    102.000000     97.000000     94.000000     94.000000
#
#           dribbling     defending        physic  movement_acceleration  \
# count  34390.000000  34390.000000  34390.000000           34390.000000
# mean      65.756063     53.904129     65.270137              68.467171
# std       10.661634     18.145844     10.403537              11.593005
# min       26.000000     15.000000     28.000000              21.000000
# 25%       60.000000     37.000000     58.000000              62.000000
# 50%       67.000000     59.000000     66.000000              69.000000
# 75%       73.000000     69.000000     73.000000              76.000000
# max       96.000000     91.000000     91.000000              97.000000
#
#        movement_sprint_speed  movement_reactions  movement_balance  \
# count           34390.000000        34390.000000      34390.000000
# mean               68.588834           65.836028         66.942629
# std                11.339010            9.762316         12.286507
# min                21.000000           30.000000         22.000000
# 25%                63.000000           59.000000         60.000000
# 50%                69.000000           66.000000         68.000000
# 75%                76.000000           73.000000         75.000000
# max                97.000000           96.000000         97.000000
#
#        power_stamina  power_strength
# count   34390.000000    34390.000000
# mean       66.907473       65.771503
# std        11.785969       13.012180
# min        26.000000       21.000000
# 25%        59.000000       58.000000
# 50%        68.000000       67.000000
# 75%        75.000000       75.000000
# max        97.000000       96.000000

# %%
df_fifa_noGK.head()
# Out:
#           short_name                            long_name player_positions  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, ST
# 1           L. Messi       Lionel Andrés Messi Cuccittini               RW
# 3          L. Suárez             Luis Alberto Suárez Díaz               ST
# 4             Neymar        Neymar da Silva Santos Júnior               LW
# 5     R. Lewandowski                   Robert Lewandowski               ST
#
#    height_cm  weight_kg      work_rate         body_type  pace  shooting  \
# 0        185         80       High/Low            Unique  90.0      93.0
# 1        170         72  Medium/Medium            Unique  89.0      90.0
# 3        182         86    High/Medium  Normal (170-185)  82.0      90.0
# 4        175         68    High/Medium            Unique  92.0      84.0
# 5        185         79    High/Medium  Normal (170-185)  81.0      88.0
#
#    passing  dribbling  defending  physic  movement_acceleration  \
# 0     82.0       90.0       33.0    80.0                     89
# 1     86.0       96.0       26.0    61.0                     92
# 3     79.0       87.0       42.0    81.0                     88
# 4     79.0       95.0       30.0    60.0                     94
# 5     75.0       86.0       38.0    82.0                     79
#
#    movement_sprint_speed  movement_reactions  movement_balance  power_stamina  \
# 0                     91                  96                63             92
# 1                     87                  95                95             73
# 3                     77                  93                60             89
# 4                     90                  88                82             78
# 5                     83                  91                80             79
#
#    power_strength season
# 0              80  18/19
# 1              59  18/19
# 3              80  18/19
# 4              53  18/19
# 5              84  18/19

# %%
df_fifa_noGK.to_csv("datasets/df_fifa_noGK.csv")
